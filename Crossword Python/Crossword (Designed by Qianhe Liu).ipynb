# %%
# %run Crossword.py
# Out:
# Welcome to Crossword!Please guess a word from the jumbled letters.
#  There are three levels of increasing difficulties. You will get 1 point for guessing one correctly in the first level, 2 points for guessing one correctly in the second level, 3 points for guessing one correctly in the third level
#  The players who take less time gets extra points, so let's see who get the most in the end!
#
# The disorganized word is： niwd
# Please enter your guessing：wind
#
# Used time 5.11 seconds
#
# Congratulations！Current points2
#  o(*≧▽≦)ツ ~
# ✧ ------------✧ Brilliant!✧ ------------✧
#
# The disorganized word is： omm
# Please enter your guessing：mom
#
# Used time 2.15 seconds
#
# Congratulations！Current points6
# ੭ ᐕ)੭*⁾⁾
# ✧ ------------✧ Fantastic!✧ ------------✧
#
# The disorganized word is： irget
# Please enter your guessing：ndksj
#
# Wrong! Already guessed it wrong for 1 times, please guess again:xdsajkb
# Wrong! Already guessed it wrong for 2 times, please guess again:xsdhks
# ...

# %%
# %run Crossword.py
# Out:
# Welcome to Crossword!Please guess a word from the jumbled letters.
#  There are three levels of increasing difficulties. You will get 1 point for guessing one correctly in the first level, 2 points for guessing one correctly in the second level, 3 points for guessing one correctly in the third level
#  The players who take less time gets extra points, so let's see who get the most in the end!
#
# The disorganized word is： bga
# Please enter your guessing：bag
#
# Used time 572.06 seconds
#
# Congratulations！Current points1
# （★＞U＜★）
# ✧ ------------✧ Fantastic!✧ ------------✧
#
# The disorganized word is： gdo
# Please enter your guessing：dog
#
# Used time 2.76 seconds
#
# Congratulations！Current points5
# (｡>∀<｡)
# ✧ ------------✧ Brilliant!✧ ------------✧
#
# The disorganized word is： enic
# Please enter your guessing：nice
#
# Used time 5930.99 seconds
#
# Congratulations！Current points6
# (｡>∀<｡)
# ✧ ------------✧ Good job!!✧ ------------✧
